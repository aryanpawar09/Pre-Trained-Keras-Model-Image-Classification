# %% [markdown]
# <a href="https://colab.research.google.com/github/aryanpawar09/Pre-Trained-Keras-Model-Image-Classification/blob/main/ImageClassification_With_PreTrained_Keras_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the Modeules

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Getting the Model and Pre-trained Weights
# We need to include models and processing packages that are specific to that model.

# %%
from tensorflow.keras.preprocessing import image

# %%
from tensorflow.keras.applications.resnet50 import ResNet50 as myModel

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input , decode_predictions

# %%
model = myModel(weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# # Loading the Image
# Let us load the image we want to classify using this model.

# %%
img_path = '/content/bag1.jpeg'

# %%
img = image.load_img(img_path , target_size=(224,224))

# %%
plt.imshow(np.asarray(img))
plt.axis('off')
# Out:
# (-0.5, 223.5, 223.5, -0.5)

# %% [markdown]
# # Predicting the Class using Pre-Trained model
# Now that we have loaded the image and the pre-trained network, we shall preprocess the image, feed it to the neural network to predict the class of the image.

# %%
x=image.img_to_array(img)

# %%
x=np.array([x])

# %%
x=preprocess_input(x)

# %%
preds=model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02769748', 'backpack', 0.5551754), ('n04235860', 'sleeping_bag', 0.34812403), ('n03709823', 'mailbag', 0.060685396)]

# %%
model.save("/content/resnet50_model.keras")

# %%
from google.colab import files
files.download("/content/resnet50_model.keras")
